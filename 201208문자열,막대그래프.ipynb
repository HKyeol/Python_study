# %% [markdown]
# <a href="https://colab.research.google.com/github/HKyeol/Python_study/blob/master/201208%EB%AC%B8%EC%9E%90%EC%97%B4%2C%EB%A7%89%EB%8C%80%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 75. 문자열에서 특정 위치의 문자 얻기
#
# 문자열에서 특정 위치의 문자를 얻는 방법은 인덱싱을 이용하는 것입니다.
# 인덱스는 0부터 시작합니다. 파이썬 인덱스는 음수도 가능합니다.
# 예제:

# %%
print('scott'[0]) # s
print('scott'[2]) # o

a = 'scott'
print(a[0])
print(a[2])
# Out:
# s
# o
# s
# o

# %% [markdown]
# 문제253. 아래의 txt 변수에서 w를 출력하시오.

# %%
txt = 'A tale that was not right'
for i in txt:
    if i == 'w':
        print(i)
        break
for i in range(0,len(txt)):
    if txt[i] == 'w':
        print(i)
        break
# Out:
# w
# 12

# %% [markdown]
# 문제254. 위의 txt 변수에서 맨 끝의 철자인 t를 출력하시오.

# %%
print(txt[-1])
# Out:
# t

# %% [markdown]
# 문제255. emp2.csv에서 이름만 출력하시오. 판다스를 이용하지 말고

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-f1a1fe5d-31c2-4218-bc9d-223c07082fe8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1a1fe5d-31c2-4218-bc9d-223c07082fe8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving emp2.csv to emp2.csv

# %%
import csv
file = open('emp2.csv')
emp_csv = csv.reader(file)
for emp_list in emp_csv:
    print(emp_list[1])
# Out:
# KING
# BLAKE
# CLARK
# JONES
# MARTIN
# ALLEN
# TURNER
# JAMES
# WARD
# FORD
# SMITH
# SCOTT
# ADAMS
# MILLER

# %% [markdown]
# 문제256. 위의 출력된 이름의 데이터 유형이 무엇인지 확인하시오.

# %%
import csv
file = open('emp2.csv')
emp_csv = csv.reader(file)
for emp_list in emp_csv:
    print(type(emp_list[1]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# 문제257. 문제255번을 다시 수행해서 emp2.csv에서 이름을 출력하는데 이름의 첫번째 철자만 출력하시오.

# %%
import csv
file = open('emp2.csv')
emp_csv = csv.reader(file)
for emp_list in emp_csv:
    print(emp_list[1][0])
# Out:
# K
# B
# C
# J
# M
# A
# T
# J
# W
# F
# S
# S
# A
# M

# %% [markdown]
# 와 신기하다!
# ```
# print(emp_list[1][0])
# ```
# 문제258. 위의 결과를 다시 출력하는 첫번째 철자가 소문자로 출력되게 하시오.

# %%
import csv
file = open('emp2.csv')
emp_csv = csv.reader(file)
for emp_list in emp_csv:
    print(emp_list[1][0].lower())
# Out:
# k
# b
# c
# j
# m
# a
# t
# j
# w
# f
# s
# s
# a
# m

# %% [markdown]
# # 76. 문자열에서 지정한 구간의 문자열 얻기(슬라이싱)
#
# 문자열에서 특정 구간에 있는 문자열을 얻으려면 슬라이싱을 이용하면 됩니다.
#
# 예제:
# ```
# print('scott'[0:2]) # sc
# a = 'scott'
# print(a[0:2]) # sc
# print(a[3:]) # tt
# print(a[:3]) # sco 문자 처음부터 읽어서 3 미만까지 출력
# ```
#
# 문제259. 아래의 SQL을 파이썬으로 구현하시오. 판다스 이용하지 말고 그냥
# ```
# SQL>
# select ename, substr(ename,1,3)
#     from emp;
# ```

# %%
import csv
file = open('emp2.csv')
result = csv.reader(file)
for i in result: 
    print(i[1][0:3])
# Out:
# KIN
# BLA
# CLA
# JON
# MAR
# ALL
# TUR
# JAM
# WAR
# FOR
# SMI
# SCO
# ADA
# MIL

# %% [markdown]
# # 77. 문자열에서 홀수 번째 문자만 추출하기
#
# 주어진 문자열에서 홀수 번째 문자만 추출하는 방법은 슬라이싱의 스텝을 이용하면 됩니다.
#
# 예제:
# ```
# txt = 'aAbBcCdDeEfFgGhHiIjJkK'
# result = txt[0: , step = 2]
# ```

# %%
txt = 'aAbBcCdDeEfFgGhHiIjJkK'
result = txt[0:]   # 0번째부터 문자끝까지 출력
print(result)
result = txt[0::2] # 문자열에서 2칸씩 건너뛰면서 출력
print(result)
# Out:
# aAbBcCdDeEfFgGhHiIjJkK
# abcdefghijk

# %% [markdown]
# 건너뛰어서 출력하는 방법 ::이다.
#
# 문제260. 위의 txt 문자열에서 짝수번째 철자들만 출력하시오.

# %%
txt = 'aAbBcCdDeEfFgGhHiIjJkK'
print(txt[1::2])
# Out:
# ABCDEFGHIJK

# %% [markdown]
# # 78. 문자열을 거꾸로 만들기
#
# 슬라이싱을 이용하면 매우 간단하게 거꾸로 된 문자열을 얻을 수 있습니다.
# 문자열 txt를 처음부터 끝까지 스텝 -1로 슬라이싱하면 됩니다.

# %%
txt = 'aAbBcCdDeEfFgGhHiIjJkK'
print(txt[:])
print(txt[-1::-1])  # 문자열 전체를 뒤에 철자부터 앞으로 읽어라
print(txt[::]) # 문장 전체
print(txt[::1]) # 문장 전체 1스텝씩
print(txt[::-1]) # 문장 전체 앞으로 1스텝씩
# Out:
# aAbBcCdDeEfFgGhHiIjJkK
# KkJjIiHhGgFfEeDdCcBbAa
# aAbBcCdDeEfFgGhHiIjJkK
# aAbBcCdDeEfFgGhHiIjJkK
# KkJjIiHhGgFfEeDdCcBbAa

# %% [markdown]
# 문제261. 이름을 출력하는데 이름의 철자를 거꾸로 출력하시오(판다스 말고)

# %%
import csv
file = open('emp2.csv')
result = csv.reader(file)
for i in result:
    print(i[1][::-1])
# Out:
# GNIK
# EKALB
# KRALC
# SENOJ
# NITRAM
# NELLA
# RENRUT
# SEMAJ
# DRAW
# DROF
# HTIMS
# TTOCS
# SMADA
# RELLIM

# %% [markdown]
# # 79. 두 개의 문자열 합치기(+)
#
# 두개의 문자열을 합치는 방법은 매우 간단합니다.
# 문자열1 + 문자열2 + 문자열3으로 + 연산자를 이용하면 됩니다.
#
# 예제:

# %%
a = 'scott'
b = 'king'
print(a + b)
# Out:
# scottking

# %% [markdown]
# 문제262. 아래의 SQL을 파이썬으로 구현하시오! (emp2.csv를 이용하세요)
# ```
# SQL>
# select ename || job
#     from emp;
# ```

# %%
import csv
file = open('emp2.csv')
result = csv.reader(file)
for i in result:
    print(i[1]+i[2])
# Out:
# KINGPRESIDENT
# BLAKEMANAGER
# CLARKMANAGER
# JONESMANAGER
# MARTINSALESMAN
# ALLENSALESMAN
# TURNERSALESMAN
# JAMESCLERK
# WARDSALESMAN
# FORDANALYST
# SMITHCLERK
# SCOTTANALYST
# ADAMSCLERK
# MILLERCLERK

# %% [markdown]
# 문제263. 아래와 같이 결과가 출력되게 하시오!
# ```
# SQL>
# select ename ||'의 직업은 ' || job || '입니다.'
#     from emp;
# ```

# %%
import csv
file = open('emp2.csv')
result = csv.reader(file)
for i in result:
    print(i[1]+'의 직업은 '+i[2]+'입니다.')
# Out:
# KING의 직업은 PRESIDENT입니다.
# BLAKE의 직업은 MANAGER입니다.
# CLARK의 직업은 MANAGER입니다.
# JONES의 직업은 MANAGER입니다.
# MARTIN의 직업은 SALESMAN입니다.
# ALLEN의 직업은 SALESMAN입니다.
# TURNER의 직업은 SALESMAN입니다.
# JAMES의 직업은 CLERK입니다.
# WARD의 직업은 SALESMAN입니다.
# FORD의 직업은 ANALYST입니다.
# SMITH의 직업은 CLERK입니다.
# SCOTT의 직업은 ANALYST입니다.
# ADAMS의 직업은 CLERK입니다.
# MILLER의 직업은 CLERK입니다.

# %% [markdown]
# # 80. 문자열을 반복해서 새로운 문자열로 만들기(*)

# %%
print('★'*10)
print('여러분~ '*5)
# Out:
# ★★★★★★★★★★
# 여러분~ 여러분~ 여러분~ 여러분~ 여러분~

# %% [markdown]
# 문제264. 숫자 1부터 5까지 출력하시오.

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 문제265. 숫자를 물어보게하고 숫자를 입력하면 해당 숫자까지 숫자가 출력되게하시오.

# %%
a = int(input('숫자를 입력하세요 ~'))
for i in range(1,a+1):
    print(i)
# Out:
# 숫자를 입력하세요 ~0

# %% [markdown]
# 문제266. 위의 코드를 수정해서 숫자를 물어보게 하고 아래와 같이 ★이 출력되게 하시오.
# ```
# 숫자를 입력하시오 ~ 5
# ★
# ★★
# ★★★
# ★★★★
# ★★★★★
# ```

# %%
a = int(input('숫자를 입력하시오 ~'))
for i in range(1,a+1):
    print('★'*i)
# Out:
# 숫자를 입력하시오 ~6
# ★
# ★★
# ★★★
# ★★★★
# ★★★★★
# ★★★★★★

# %% [markdown]
# 문제267. (알고리즘22번 문제) 아래와 같이 사각형이 출력되게 하시오.
# ```
# 가로의 숫자를 입력하세요 ~ 3
# 세로의 숫자를 입력하세요 ~ 5
# ```

# %%
a = int(input('가로의 숫자를 입력하시오 ~ '))
b = int(input('세로의 숫자를 입력하시오 ~ '))

for i in range(1,b+1):
    print('★'*a)
# Out:
# 가로의 숫자를 입력하시오 ~ 5
# 세로의 숫자를 입력하시오 ~ 5
# ★★★★★
# ★★★★★
# ★★★★★
# ★★★★★
# ★★★★★

# %% [markdown]
# # 81. 문자열에서 특정 문자가 있는지 확인하기(in)
#
# 문자열에서 특정 문자가 있는지 없는지 확인하려면 in 키워드를 이용합니다.
#
# 예제:

# %%
txt = 'aAbBcCdDeEfFgGhHiIjJkK'
if 'b' in txt:
    print('존재합니다')
else:
    print('존재하지 않습니다')
# Out:
# 존재합니다

# %% [markdown]
# 문제268. emp2.csv에서 이름을 출력하는데 이름에 S를 포함하고 있는 사원들의 이름을 출력하시오.
# ```
# SQL>
# select ename
#     from emp
#     where ename like '%S%';
# 파이썬>
# ```

# %%
import csv
file = open('emp2.csv')
result = csv.reader(file)
for i in result:
    if 'S' in i[1]:
        print(i[1])
# Out:
# JONES
# JAMES
# SMITH
# SCOTT
# ADAMS

# %% [markdown]
# 설명: 위의 코드는 금융감독원에서 금융사에 요청하는 것 중에 하나가 보험회사의 경우 보험상담원들이 상담할 때 적절한 보험용어를 써서 고객을 응대를 해야해서 고객과의 통화를 다 녹음을 하고 그 녹음된 내용을 text로 변환해서 그 text 안에 단어들을 일일히 확인하는 작업을 한다.(예: 30일 이라고 해야하는데 한달이라고 했다던가) 이럴 때 응용될 수 있는 코드입니다.

# %% [markdown]
# 문제269. 문제268번 코드를 수정해서 출력하는데 이름에 S자가 포함된 사원이 몇명인지 출력하시오.

# %%
import csv
file = open('emp2.csv')
result = csv.reader(file)
cnt = 0
for i in result:
    if 'S' in i[1]:
        cnt += 1
print(cnt)
# Out:
# 5

# %% [markdown]
# # 82. 문자열에서 특정 문자열이 있는지 확인하기(in)
# 보험회사에서 보험 상담원분들이 상담하실 때의 상담내용중에 부적절한 용어가 있는지 없는지를 확인하여 금융감독원에 보고를 해야하는데 이 확인작업을 사람이 하려면 많은 인력과 시간이 드니까 파이썬으로 쉽게 할 수 있도록 프로그래밍 할 때 문자열에서 문자열이 있는지 확인하는 코드를 작성하면 됩니다.
#
# 예제: 겨울왕국 스크립트에서 elsa라는 단어(문자열)가 몇번 나오는지 카운트 해봅니다.
#
# 예제1: 겨울왕국(winter.txt) 스크립트를 파이썬으로 불러와서 출력하시오.

# %%
myfile = files.upload()
winter = open('winter1.txt')
for i in winter:
    print(i)
# Out:
#      <input type="file" id="files-291200fb-7284-4812-9527-d74fc266a8ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-291200fb-7284-4812-9527-d74fc266a8ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# ANNA
#
# ...Sandwiches.
#
# KRISTOFF
#
# Best friend’s name?
#
# ANNA
#
# Probably John.
#
# KRISTOFF
#
# Eye color.
#
# ANNA
#
# Dreamy.
#
# KRISTOFF
#
# Foot size...?
#
# ANNA
#
# Foot size doesn’t matter.
#
# KRISTOFF
#
# Have you had a meal with him yet?
#
# What if you hate the way he eats?
#
# What if you hate the way he picks
#
# his nose?
#
# ANNA
#
# Picks his nose?
#
# FROZEN - J. Lee 46
#
# KRISTOFF
#
# And eats it.
#
# ANNA
#
# Excuse me, sir. He’s a prince.
#
# KRISTOFF
#
# All men do it.
#
# ANNA
#
# ...

# %% [markdown]
# UTf-8이라 에러나네 설정 바꾸고 다시 업로드 winter1으로.
#
# 문자를 소문자로 출력하자.

# %%
winter = open('winter1.txt')
for i in winter:
    print(i.lower())

# %% [markdown]
# 예제3. 위에서 소문자로 출력된 스크립트 한 행을 하나 가져와서 아래와 같이 실행하면 뭐가 나올까?

# %%
if 'elsa' in 'olaf skates and helps elsa coach anna.':
    print('존재합니다.')
else:
    print('존재하지 않습니다.')
# Out:
# 존재합니다.

# %% [markdown]
# 예제4. 엘사 몇번이나 나오는지 확인해보자.

# %%
winter = open('winter1.txt')
cnt = 0
for i in winter: # winter의 스크립트를 한 행씩 가져온다.
   if 'anna' in i.lower(): # elsa가 2번 나올 수 있으므로 틀린 코드이다.
        cnt += 1
print(cnt)
# Out:
# 677

# %% [markdown]
# 설명: 위의 코드는 한 행에 elsa가 2번 나와도 cnt는 하나만 카운트 됩니다. 정확하게 하려면 위의 문자열에 elsa가 2개가 나오니까 cnt가 2개가 되어야 합니다.
#
# 예제5.winter.txt를 한 행씩 읽어서 어절 단위로 출력되게 하시오!

# %%
winter = open('winter1.txt')
winter2 = winter.read().split(' ') # 스크립트를 공백단위로 분리해라 ~
for i in winter2: # winter의 스크립트를 한 행씩 가져온다.
    print(i.lower()) # elsa가 2번 나올 수 있으므로 틀린 코드이다.

# %% [markdown]
# 문제270. (점심시간 문제) 겨울왕국 스크립트에서 엘사라는 단어가 몇번이나 나왔는지 출력하라

# %%
winter = open('winter1.txt')
winter2 = winter.read().split(' ') # 스크립트를 공백단위로 분리해라 ~
cnt = 0
for i in winter2: # winter의 스크립트를 한 행씩 가져온다.
    if 'elsa' in i.lower(): # elsa가 2번 나올 수 있으므로 틀린 코드이다.
        cnt += 1
print(cnt)
# Out:
# 318

# %% [markdown]
# 세원이형 답. 이게 답이다.

# %%
winter = open("winter1.txt")
winter2 = winter.read().split() # \n = 엔터 어절별로 분류하기 전에 먼저 엔터로 줄 단위로 분류함

cnt = 0
for i in winter2:
    for j in i.split(' '): # 어절 분리
        if 'anna' in j.lower():
            cnt +=1
            print(j,cnt)
# Out:
# ANNA 1
# ANNA 2
# Anna 3
# ANNA 4
# Anna, 5
# Anna 6
# ANNA 7
# Anna 8
# Anna 9
# ANNA 10
# Anna, 11
# ANNA 12
# Anna’s 13
# ANNA 14
# Anna 15
# ANNA 16
# Anna 17
# -Anna 18
# Anna 19
# ANNA 20
# -Anna 21
# -Anna 22
# ANNA 23
# Anna. 24
# Anna 25
# ANNA 26
# Anna 27
# Anna 28
# ANNA! 29
# Anna 30
# Anna’s 31
# Anna) 32
# Anna! 33
# Anna 34
# Anna. 35
# Anna) 36
# Anna. 37
# Anna 38
# Anna) 39
# Anna’s 40
# Anna. 41
# -Anna 42
# -Anna 43
# Anna 44
# Anna 45
# Anna 46
# ANNA 47
# Anna 48
# ANNA 49
# ANNA’S 50
# Anna 51
# ANNA 52
# Anna 53
# ANNA 54
# -Anna 55
# ANNA 56
# Anna. 57
# ANNA 58
# Anna, 59
# ANNA 60
# Anna 61
# ANNA 62
# Anna 63
# ANNA 64
# Anna 65
# ANNA 66
# ANNA 67
# Anna, 68
# ANNA 69
# Anna’s 70
# ANNA 71
# Anna, 72
# Anna 73
# ANNA 74
# Anna 75
# Anna, 76
# ANNA 77
# Anna 78
# ANNA 79
# Anna. 80
# ANNA’S 81
# Anna, 82
# Anna...? 83
# Anna 84
# ANNA 85
# ANNA 86
# ANNA 87
# ANNA 88
# ANNA 89
# ANNA 90
# Anna 91
# ANNA 92
# -Anna 93
# ANNA 94
# ANNA 95
# -Anna 96
# ...

# %% [markdown]
# 횟수 318이 틀린 이유:
#
# 304 다음에 elsa가 3개 있으므로 305가 되면 안되는데 305가 된 이유는 confidence. anna elsa? elsa love. elsa를 하나의 문장으로 보았기 때문입니다. 어절별로 분리한걸로 코드를 구현했지만 실제로는 어절별로 분리가 되지 않았습니다. 그래서 위와같은 실수를 하지 않으려면 해결하는 방법은?
#
# 먼저 스크립트를 행단위로 먼저 분리를 하고 나서 어절별로 분리해야 합니다.

# %% [markdown]
# # 83. 문자열 길이 구하기(len)
#
# 예제:

# %%
a = 'scott'
print(len(a))
# Out:
# 5

# %% [markdown]
# 문제271. 이름, 이름의 길이를 출력하시오. 파이썬으로

# %%
import csv
emp = open('emp3.csv')
result = csv.reader(emp)
for i in result:
    print(i[2],len(i[2]))
# Out:
# ename 5
# KING 4
# BLAKE 5
# CLARK 5
# JONES 5
# MARTIN 6
# ALLEN 5
# TURNER 6
# JAMES 5
# WARD 4
# FORD 4
# SMITH 5
# SCOTT 5
# ADAMS 5
# MILLER 6

# %% [markdown]
# # 84. 문자역일 알파벳인지 검사하기 (isalpha)
#
# 문자열은 문자나 숫자, 기호들로 구성이 됩니다. 코드를 작성하다 보면 특정 문자열이 한글이나 알파벳과 같이 사람의 언어를 표현하기위해 사용되는 문자로만 구성되어 있는지 확인해야 하는 경우가 있습니다. 파이썬 문자열 객체가 제공하는 메소드인 isalpha()는 주어진 문자열이 사람의 언어 문자로만 구성되어 있는지 확인해줍니다.
#
# 예제:

# %%
txt1 = 'warcraft three'
txt2 = '안녕'
txt3 = '3PO'
print(txt1.isalpha())  # 공백때문에 false가 나온 것
print(txt2.isalpha())  # 한글 말고 다른나라 언어도 된다.
print(txt3.isalpha())  #
# Out:
# False
# True
# False

# %%
txt1 = 'warcraft three'
txt2 = '안녕'
txt3 = '3PO'
for i in range(1,4):
    print(f'txt{i}')
# Out:
# txt1
# txt2
# txt3

# %% [markdown]
# 문제272. 스티븐 잡스 연설문인 jobs.txt를 한행 한행씩 출력하시오.

# %%
#myfile = files.upload()
stev = open('jobs.txt')
stev = stev.read().split('\n') # 한 행씩 분리하는 작업
for i in stev:                 # 한 행씩 분리된 스크립트를 한 행씩 가져오는 작업
    print(i)

# %% [markdown]
# 문제273. 위에서 한 행씩 출력하고 있는 스크립트를 철자 하나씩 출력하시오.

# %%
stev = open('jobs.txt')
stev = stev.read().split('\n') # 한 행씩 분리하는 작업
for i in stev:                 # 한 행씩 분리된 스크립트를 한 행씩 가져오는 작업
    for j in i:                # 스크립트 한 행을 읽어서 철자를 하나씩 불러오는 코드
        print(j)

# %% [markdown]
# 문제274. 위에서 출력된 철자가 알파벳이면 cnt를 증가시켜서 스티븐 잡스 연설문에 알파벳이 몇개가 있는지 출력하시오.

# %%
stev = open('jobs.txt')
stev = stev.read().split('\n') # 한 행씩 분리하는 작업
cnt = 0
for i in stev:                 # 한 행씩 분리된 스크립트를 한 행씩 가져오는 작업
    for j in i:                # 스크립트 한 행을 읽어서 철자를 하나씩 불러오는 코드
        if j.isalpha() == True:
            cnt += 1
print(cnt)
# Out:
# 9255

# %% [markdown]
# 설명: 스티븐 잡스 연설문에서 숫자나 공백문자나 마침표와 같은 구두점을 뺀 알파벳 철자만 카운트 했습니다. 데이터 분석 사례중에 유명한 사례 중 하나가 케냐의 은행에서 고객들에게 대출을 해줄 때 그 사람의 신용을 확인해서 대출을 해주는데 신용을 확인할 때 sns의 그 사람에 대한 글을 분석해서 긍정적인 평가가 많은지 부정적인 평가가 많은지를 파악해서 대출여부심사에 반영을 하니까 훨씬 은행의 대출금 환수가 원활해졌던 사례에서 사용되고 있습니다.

# %%
winter = open("winter1.txt")
winter2 = winter.read().split("\n")

cnt = 0
for i in winter2:
    for j in i.split(' '):
        if 'anna' in j.lower():
            if 'wanna' in j.lower():
                continue
            elif 'vanna' in j.lower():
                continue
            elif 'moreanna' in j.lower():
                continue
            else:
                cnt+=1
                print(i,'  ',j,cnt)

# %% [markdown]
# # 85. 문자열이 숫자인지 검사하기(isdigit)
#
# 문자열 객체의 isdigit() 메소드는 문자열을 구성하는 요소가 모두 숫자인지 체크하고 True 또는 False로 리턴합니다.
# ```
# 번호    내장함수     설명
#   1     isalpha()    알파벳(한글)이 맞는지 확인
#   2     isdigit()    숫자가 맞는지 확인
#   3     isspace()    공백이 맞는지 확인
# ```
#
# 문제275. 스티븐잡스 연설문에는 숫자가 몇개가 있는지 출력하시오.

# %%
stev = open('jobs.txt')
stev = stev.read().split('\n') # 한 행씩 분리하는 작업
cnt = 0
for i in stev:                 # 한 행씩 분리된 스크립트를 한 행씩 가져오는 작업
    for j in i:                # 스크립트 한 행을 읽어서 철자를 하나씩 불러오는 코드
        if j.isdigit() == True:
            cnt += 1
print(cnt)

# %% [markdown]
# # 86. 문자열이 알파벳 또는 숫자인지 검사하기(isalnum)
#
# 알파벳(한글)과 숫자를 동시에 확인하는 문자열 함수는 isalnum입니다.
#
# 예제:

# %%
a = 'A story is 2003'
for i in a:
    if i.isalnum() == True:
        print(i)
# Out:
# A
# s
# t
# o
# r
# y
# i
# s
# 2
# 0
# 0
# 3

# %% [markdown]
# 공백문자 안나오고 알파벳이랑 숫자만 나옴
#
# * 케냐 은행의 데이터 분석 사례를 파이썬 코드로 구현해 봅니다.
#
# 예제1. 긍정단어(positive-word.txt)를 파이썬으로 읽어서 한행씩 출력하시오.

# %%
myfiles = files.upload()

# %%
positive = open('positive-words.txt')
#positive = csv.reader(positive)
pos = positive.read().split('\n')
for i in pos:
    print(i)

# %% [markdown]
# 예제2. 아래의 pos를 프린트해보세요

# %%
print(pos) # positive 스크립트행을 엔터로 구분한 단어들을 pos에 담습니다.

# %% [markdown]
# 맨 마지막을 보면 ] 대괄호로 닫혀있다. 리스트에 담긴 것이다. 타입을 보자

# %%
type(pos)
# Out:
# list

# %% [markdown]
# pos의 자료형은 list이다. 긍정단어들이 리스트에 담겼다. 리스트 이름은 pos입니다.
#
# 예제3. 아래의 단어가 긍정단어 리스트들 중에 있는지 확인하시오.

# %%
if 'wonderful' in ['wonderful', 'wonderfully', 'wonderous', 'wonderously']:
    print('존재합니다.')
else:
    print('존재하지 않습니다.')

if 'wonderful' in pos:
    print('존재합니다.')
else:
    print('존재하지 않습니다.')
# Out:
# 존재합니다.
# 존재합니다.

# %% [markdown]
# 예제4. 스티븐 잡스 연설문(jobs.txt)를 읽어서 한 단어씩 출력하시오.

# %%
positive = open('positive-words.txt')
pos = positive.read().split()
stev = open('jobs.txt')
stev2 = stev.read().split()

cnt = 0
for i in stev2:
    if i in pos:
        print(i)
        cnt += 1
print(cnt)

# %% [markdown]
# 문제276. 스티븐잡스 연설문에는 긍정단어가 몇개가 있는지 확인하세요.

# %%
positive = open('positive-words.txt')
pos = positive.read().split()
stev = open('jobs.txt')
stev2 = stev.read().split()

 

cnt = 0
for i in stev2:
    if i in pos:
        cnt += 1
print(cnt)
# Out:
# 66

# %% [markdown]
# # 87. 문자열에서 대소문자 변환하기(upper, lower)
# 문자열 객체의 upper() 메소드는 문자열에 있는 모든 알파벳을 대문자로 변환한 결과를 리턴합니다. 문자열 객체의 lower() 메소드는 문자열에 있는 모든 알파벳을 소문자로 변환한 결과를 리턴합니다.
#
# 예제:

# %%
txt = 'A lot of things occur each day'
result1 = txt[0].upper()+txt[1:]
result2 = txt.lower()
print(result1)
print(result2)
# Out:
# A lot of things occur each day
# a lot of things occur each day

# %% [markdown]
# 문제277. emp2.csv에서 이름과 월급을 출력하시오.

# %%
import csv
emp = open('emp2.csv')
emp = csv.reader(emp)
for i in emp:
    print(i[1],i[5])
# Out:
# KING 5000
# BLAKE 2850
# CLARK 2450
# JONES 2975
# MARTIN 1250
# ALLEN 1600
# TURNER 1500
# JAMES 950
# WARD 1250
# FORD 3000
# SMITH 800
# SCOTT 3000
# ADAMS 1100
# MILLER 1300

# %% [markdown]
# 문제278. 이름을 물어보게 하고 이름을 입력하면 해당 사원의 이름과 월급이 출력되게 하는데 소문자로 입력하던 대문자로 입력하던 잘 출력되게 하시오.

# %%
emp = open('emp2.csv')
emp = csv.reader(emp)
a = input('이름이 무엇인가요? ')
for i in emp:
    if i[1] == a.upper():
        print(i[1],i[5])
        break
# Out:
# 이름이 무엇인가요? scott
# SCOTT 3000

# %% [markdown]
# # 88. 문자열에서 좌우 공백 제거하기(lstrip, rstrip, strip)
# ```
# 함수      설명
# lstrip()  문자열에서 존재하는 왼쪽 공백을 제거
# rstrip()  문자열에서 존재하는 오른쪽 공백을 제거
# strip()   문자열에서 존재하는 양쪽 공백을 제거
# ```
# 예제:

# %%
txt7 = '      양쪽에 공백이 있는 문자열입니다.      '
print(txt7)
print(txt7.lstrip())
print(txt7.rstrip())
print(txt7.strip())
# Out:
#       양쪽에 공백이 있는 문자열입니다.
# 양쪽에 공백이 있는 문자열입니다.
#       양쪽에 공백이 있는 문자열입니다.
# 양쪽에 공백이 있는 문자열입니다.

# %% [markdown]
# 문제279. 스티븐 잡스 연설문에서는 정관사 The가 몇번 나오는가?

# %%
stev = open('jobs.txt')
#stev = csv.reader(stev)
stev = stev.read().split()
cnt = 0
for i in stev:
    if i.lower().strip() == 'the':  # 양쪽에 공백이 있을지 모르므로 확인사살 코드
        cnt += 1
print(cnt)
# Out:
# 98

# %% [markdown]
# # 89. 문자열에서 문자 개수 구하기(count)
#
# 문자열 객체의 count() 메소드는 문자열에서 특정 문자의 갯수를 리턴합니다.

# %%
txt = 'A lot of things occur each day. Today is beautiful day.'
txt.count('day') # txt에서 day 단어의 건수를 확인
# Out:
# 3

# %% [markdown]
# 문제280. 안철수 연설문에서는 국민이라는 단어가 몇 번 나오는지 카운트 하시오.

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-013b3102-f731-4209-b450-61c0d6886315" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-013b3102-f731-4209-b450-61c0d6886315">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ahn.txt to ahn.txt

# %%
import csv
ahn = open('ahn.txt',encoding = 'UTF8') 
ahn = ahn.read()                        # split 안했으니까 그냥 안철수 연설문을 읽어서 통채로 ahn에 입력한다.
ahn.count('국민')                       # 안철수 연설문에서 국민이라는 단어가 몇개 있는지 출력한다.
# Out:
# 22

# %% [markdown]
# 먼저 스플릿 하지 않고 그냥 읽는다. .read()
# 그다음에 count 돌리면 된다.

# %% [markdown]
# # 파이썬에서 막대그래프 그리는 방법

# %%
import matplotlib.pyplot as plt

y_value = [21.6, 23.6, 45.8, 77.0]
x_value = [0,1,2,3]

plt.bar(x_value,y_value,color='red')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 문제281. 동전을 10번 던져서 앞면이 2개가 나오는 지난번 마지막 문제의 확률 10개를 가지고 막대그래프를 그리시오.

# %%
def coin_prob(N,num1):
  import numpy as np
  import math as m
#  num1 = int(input('몇개가 뽑혔을 때의 확률을 알고싶나요?'))
#  N = int(input('몇번 던지실 건가요?'))

  P = 0.5
  Q = 1-P

  if num1 > N:
    print('던진 숫자보다 많이 뽑힐 수 없습니다.')
  else:
    cnt = m.log10(1)
    cnt2 = m.log10(1)

    if num1 < N - num1:  # 확률이 정확히 같은 코인에서만 가능합니다! 속도를 위해 넣었습니다. 확률이 바뀌는 경우 이부분을 수정해주어야 합니다!
      num1 = N - num1

    for i in range(N,num1,-1):
      cnt += m.log10(i)
    for j in range(N-num1,0,-1):
      cnt2 += m.log10(j)
    nCr = cnt-cnt2
    prob = m.log10(P)*N        # 확률이 정확히 같은 코인에서만 가능합니다! 확률이 바뀌는 경우 P**num1*Q**(N-num1)로 수정해주어야 합니다.
    return(f'{10**(nCr+prob)}')
#    print(f'{nCr*prob*100}%') # 로그보다 로그10이 더 빠른 것같다. 그러면 로그2는? 로그2가 좀 더 빠르다 근데 답이 달라지네 수정해야겠다.

# %%
x_index = []
y_value = []
for i in range(0,11):
    y_value.append(coin_prob(10,i))
    x_index.append(i)

plt.bar(x_index,y_value,color='red')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 문제282. 위의 그래프의 결과에 제목, x축 라벨과 y축 라벨을 같이 출력하시오.

# %%
import matplotlib.pyplot as plt
x_index = []
y_value = []
for i in range(0,11):
    y_value.append(coin_prob(10,i))
    x_index.append(i)
plt.bar(x_index,y_value,color='red')
plt.title('Coin Probability') # 그래프 제목
plt.xlabel('cnt')
plt.ylabel('probability')
plt.show()

# %% [markdown]
# 라벨이 붙는다. 내 화면이 어두워서 잘 안보이지만 붙는다.
#
# 문제283. 지난번 마지막 문제인 동전을 10번 던져서 앞면이 2개 나오는 아래의 확률 결과를 가지고 막대그래프로 시각화 하시오!

# %%
import matplotlib.pyplot as plt
x_index = []
y_value = []
for i in range(0,11):
    y_value.append(coin_prob(10,i))
    x_index.append(i)
plt.bar(x_index,y_value,color='red')
plt.title('Coin Probability') # 그래프 제목
plt.xlabel('cnt')
plt.ylabel('probability')
plt.show()
